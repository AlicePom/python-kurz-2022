# %%
import pandas as pd

# %% [markdown]
# ### Úkol 11 - zadání

# %%
platy = pd.read_csv('platy_2021_02.csv', index_col='cislo_zamestnance')
# platy.shape # 43 řádků
# platy.min() # 31400.0
# platy.max() # 59600.0
platy.sort_values(['plat'], ascending=True)
# Out:
#                       plat
# cislo_zamestnance
# 63                 31400.0
# 95                 31600.0
# 38                 32600.0
# 69                 32600.0
# 40                 32800.0
# 30                 33500.0
# 16                 34200.0
# 22                 34400.0
# 18                 35400.0
# 7                  36400.0
# 34                 36800.0
# 57                 36800.0
# 64                 36900.0
# 51                 37100.0
# 28                 38100.0
# 33                 38400.0
# 84                 38600.0
# 23                 39000.0
# 56                 39300.0
# 47                 40700.0
# 90                 41100.0
# 85                 44200.0
# 24                 44200.0
# 27                 45100.0
# 83                 46500.0
# 8                  47900.0
# 92                 48100.0
# 29                 48900.0
# 74                 49300.0
# 41                 49300.0
# 87                 49900.0
# 96                 50200.0
# ...

# %%
# platy.plot(kind='hist', bins=6, grid=True, color='purple') # pův. řešení, nelíbilo se mi tolik jako varianta viz níže
platy.plot(kind='hist', bins=[30_000, 35_000, 40_000, 45_000, 50_000, 55_000, 60_000], grid=True, color='purple', ylim=(0, 12))
# zde jsem zvolila rozdělení platů do 6 kategorií po 5 tisících v rozmezí od 30 do 60 tisíc
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Nepovinný bonus 1

# %%
import pytemperature

teploty = pd.read_csv('temperature.csv')
teploty["AvgTemperatureCelsia"] = pytemperature.f2c(teploty["AvgTemperature"])
teploty_HMBT = teploty[teploty.City.isin(['Helsinki', 'Miami Beach', 'Tokyo'])][['City', 'AvgTemperatureCelsia']].set_index('City')
teploty_HMBT.sort_values(['AvgTemperatureCelsia'], ascending=False)
# Out:
#              AvgTemperatureCelsia
# City
# Miami Beach                 27.11
# Miami Beach                 26.78
# Miami Beach                 26.67
# Miami Beach                 26.50
# Miami Beach                 26.22
# ...                           ...
# Helsinki                     0.56
# Helsinki                     0.22
# Helsinki                     0.17
# Helsinki                    -1.33
# Helsinki                    -1.39
#
# [90 rows x 1 columns]

# %%
# teploty.plot(kind='box', index_col='City')
""" helsinki = teploty_HMBT.to_frame(teploty_HMBT.City == 'Helsinki')
miami_beach = teploty_HMBT.to_frame(teploty_HMBT.City == 'Miami Beach')
tokyo = teploty_HMBT.to_frame(teploty_HMBT.City == 'Tokyo') """
# helsinki = pd.Series(teploty_HMBT.City == 'Helsinki')['AvgTemperature'] Ne
# columns = [teploty_HMBT.City == 'Helsinki', teploty_HMBT.City == 'Miami Beach', teploty_HMBT.City == 'Tokyo']
# teploty_HMBT.plot(kind='box', xlabel='City', columns=['Helsinki', 'Miami Beach', 'Tokyo'], ylabel='AvgTemperatureCelsia')
# teploty = pd.DataFrame('AvgTemperatureCelsia', columns=['Helsinki', 'Miami Beach', 'Tokyo'])
#helsinki = pd.Series((teploty_HMBT.City == 'Helsinki')['AvgTemperatureCelsia'])
#helsinki.plot(kind='box')
teploty_HMBT.plot(kind='box', xlabel='City', ylabel='AvgTemperatureCelsia')

#pd.DataFrame(teploty_HMBT.groupby("City")["AvgTemperatureCelsia"])
# Out:
# <Axes: xlabel='City', ylabel='AvgTemperatureCelsia'>
